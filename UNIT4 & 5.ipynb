# %%
import pandas as pd

# %%
df = pd.read_csv("Titanic-Dataset.csv")

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### head, tail or sample

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
#missing values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints = np.array([0,6])
ypoints = np.array([5,11])

# %%
#draw the 2 line betw point(0,6) & (5,11)
plt.plot(xpoints, ypoints)
plt.show()

# %%
plt.plot(xpoints, ypoints, '*')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("GRAPH")
plt.show()

# %%
plt.plot(xpoints, ypoints,)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("GRAPH")
plt.plot(xpoints, ypoints, linestyle= 'dotted',color = 'r', linewidth = '10.2')
plt.show()

# %%
#multiple graphs
# plot 1
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)

#plot 2
x = np.array([0,1,2,3])
y = np.array([5,15,10,30])
plt.subplot(1,2,2)
plt.plot(x,y)

plt.show()

# %%
# scatter graph (continuous numeric variables)

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,111,89,103,87,94,78,77,85,86,98])
plt.scatter(x,y)
plt.show()

# %%
plt.scatter(df["Age"],df["Fare"])
plt.show()

# %%
corr_matrix = df.corr()
print(corr_matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 corr_matrix = df.corr()
#       2 print(corr_matrix)
#
# File ~/Desktop/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Desktop/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
plt.bar(df["Sex"],df["Survived"])
plt.show()

# %%
plt.hist(df["Age"])
plt.show()

# %%
a = df['Sex'].value_counts()
print(a)
plt.pie(x=a,autopct='%.2f')

plt.show()

# %%
import seaborn as sns

# %%
sns.histplot(df['Age'], bins=5)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# # UNIT 5

# %% [markdown]
# ### Missing Data Treatment

# %%
df.isnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.isnull()
#
# NameError: name 'df' is not defined

# %%
df.isnull().sum()
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin             0
# Embarked          0
# age_Normalised    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PassengerId     891 non-null    int64
#  1   Survived        891 non-null    int64
#  2   Pclass          891 non-null    int64
#  3   Name            891 non-null    object
#  4   Sex             891 non-null    object
#  5   Age             891 non-null    float64
#  6   SibSp           891 non-null    int64
#  7   Parch           891 non-null    int64
#  8   Ticket          891 non-null    object
#  9   Fare            891 non-null    float64
#  10  Cabin           891 non-null    object
#  11  Embarked        891 non-null    object
#  12  age_Normalised  891 non-null    float64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 90.6+ KB

# %%
df["Age"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df["Age"]
#
# NameError: name 'df' is not defined

# %%
mean = df["Age"].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 mean = df["Age"].mean()
#
# NameError: name 'df' is not defined

# %%
df["Age"].fillna(mean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df["Age"].fillna(mean)
#
# NameError: name 'df' is not defined

# %%
df.isnull().sum()
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin             0
# Embarked          0
# age_Normalised    0
# dtype: int64

# %%
df["Age"].fillna(df["Age"].mean(), inplace=True)             #OR df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df.isnull().sum()
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin             0
# Embarked          0
# age_Normalised    0
# dtype: int64

# %%
mode_value = df['Embarked'].mode()[0]
df['Embarked'].fillna(mode_value, inplace = True)
# Out:
# /var/folders/n0/gg36txq91798f2s7lkdqhl240000gn/T/ipykernel_1069/2570870942.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna(mode_value, inplace = True)

# %%
mode_value = df['Cabin'].mode()[0]
df['Cabin'].fillna(mode_value, inplace = True)
# Out:
# /var/folders/n0/gg36txq91798f2s7lkdqhl240000gn/T/ipykernel_1069/1022850983.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cabin'].fillna(mode_value, inplace = True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# delete duplicate by:
# df= df.drop(3) #delete row with index 3
# df = df.drop([2, 5, 7])
# df = df[df['age']>25] # by condition
#
# columns deleted by:
# df = df.drop('column_name' , axis=1) OR del df...

# %%
df.cov(numeric_only=True)
# Out:
#                  PassengerId  Survived     Pclass           Age      SibSp  \
# PassengerId     66231.000000 -0.626966  -7.561798   1111.130416 -16.325843
# Survived           -0.626966  0.236772  -0.137703     -4.416563  -0.018954
# Pclass             -7.561798 -0.137703   0.699015    -36.018549   0.076599
# Age              1111.130416 -4.416563 -36.018549  16905.239994 -33.353450
# SibSp             -16.325843 -0.018954   0.076599    -33.353450   1.216043
# Parch              -0.342697  0.032017   0.012429    -18.779868   0.368739
# Fare              161.883369  6.221787 -22.830196    591.622003   8.748734
# age_Normalised      1.396243 -0.005550  -0.045261     21.243076  -0.041912
#
#                     Parch         Fare  age_Normalised
# PassengerId     -0.342697   161.883369        1.396243
# Survived         0.032017     6.221787       -0.005550
# Pclass           0.012429   -22.830196       -0.045261
# Age            -18.779868   591.622003       21.243076
# ...

# %%
corr_matrix = df.corr(numeric_only=True)
print(corr_matrix)
# Out:
#                 PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId        1.000000 -0.005007 -0.035144  0.033207 -0.057527 -0.001652
# Survived          -0.005007  1.000000 -0.338481 -0.069809 -0.035322  0.081629
# Pclass            -0.035144 -0.338481  1.000000 -0.331339  0.083081  0.018443
# Age                0.033207 -0.069809 -0.331339  1.000000 -0.232625 -0.179191
# SibSp             -0.057527 -0.035322  0.083081 -0.232625  1.000000  0.414838
# Parch             -0.001652  0.081629  0.018443 -0.179191  0.414838  1.000000
# Fare               0.012658  0.257307 -0.549500  0.091566  0.159651  0.216225
# age_Normalised     0.033207 -0.069809 -0.331339  1.000000 -0.232625 -0.179191
#
#                     Fare  age_Normalised
# PassengerId     0.012658        0.033207
# Survived        0.257307       -0.069809
# Pclass         -0.549500       -0.331339
# Age             0.091566        1.000000
# SibSp           0.159651       -0.232625
# ...

# %%
df.corr(numeric_only=True)['Survived']
# Out:
# PassengerId      -0.005007
# Survived          1.000000
# Pclass           -0.338481
# Age              -0.069809
# SibSp            -0.035322
# Parch             0.081629
# Fare              0.257307
# age_Normalised   -0.069809
# Name: Survived, dtype: float64

# %% [markdown]
# # Data Transform Commands

# %%
print("Original Age Column")
print(df['Age'])
# Out:
# Original Age Column
# 0      220.000000
# 1      380.000000
# 2      260.000000
# 3      350.000000
# 4      350.000000
#           ...
# 886    270.000000
# 887    190.000000
# 888    296.991176
# 889    260.000000
# 890    320.000000
# Name: Age, Length: 891, dtype: float64

# %%
#Multiply age by 10
df['Age'] = df['Age'].transform(lambda x: x*10)

# %%
print("\nAfter multiplying Age by 10:")
print(df['Age'].head())
# Out:
# After multiplying Age by 10:
# 0    2200.0
# 1    3800.0
# 2    2600.0
# 3    3500.0
# 4    3500.0
# Name: Age, dtype: float64

# %% [markdown]
# # Scaling: Standardization/ Normalization

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
scaler = MinMaxScaler()
df['age_Normalised'] = scaler.fit_transform(df[['Age']])

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex     Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  2200.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  3800.0      1
#
#    Parch     Ticket     Fare    Cabin Embarked  age_Normalised
# 0      0  A/5 21171   7.2500  B96 B98        S        0.271174
# 1      0   PC 17599  71.2833      C85        C        0.472229

# %%
df['age_Normalised'].min()
# Out:
# 0.0

# %%
df['age_Normalised'].max()
# Out:
# 1.0

# %%
sns.box(x=
# Out:
#   Cell In[70], line 1
#     sns.box(x=
#               ^
# _IncompleteInputError: incomplete input

# %%
sns.countplot(x =df['Survived'], data = df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.histplot(df['Age'], bins=5)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# # Heatmap (Correlation)

# %%
corr_matrix = df.corr(numeric_only = True)
sns.heatmap(corr_matrix, cmap= "Greens", annot= True)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'age_Normalised'],
#       dtype='object')

# %%
avg_age = df.groupby('Pclass') ['Age'].mean()
print(avg_age)
# Out:
# Pclass
# 1    3704.811819
# 2    2986.695812
# 3    2640.325866
# Name: Age, dtype: float64

# %%
values = df["Pclass"].sort_values().unique()
print(values)
# Out:
# [1 2 3]

# %%
sns.barplot(x= values, y =avg_age)
# Out:
# <Axes: ylabel='Age'>

# %%
avg_fare = df.groupby('Pclass') ['Fare'].mean()
print(avg_fare)
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
gen_counts = df['Sex'].value_counts()
mylabels =df['Sex'].unique()
print(gen_counts)
print(mylabels)
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64
# ['male' 'female']

# %%
plt.pie(gen_counts,labels= mylabels)
# Out:
# ([<matplotlib.patches.Wedge at 0x1371aa660>,
# ...
#  [Text(-0.4919454315896098, 0.9838646717603559, 'male'),
#   Text(0.49194551760179267, -0.9838646287531149, 'female')])

# %%
youngest = df[['Name' , 'Age' , 'Pclass']].sort_values(by='Age')
print("Top 5 youngest passengers:")
print(youngest.head(5))
print("\nTop 5 oldest passengers:")
print(youngest.tail(5))
# Out:
# Top 5 youngest passengers:
#                                 Name   Age  Pclass
# 803  Thomas, Master. Assad Alexander  42.0       3
# 755        Hamalainen, Master. Viljo  67.0       2
# 469    Baclini, Miss. Helene Barbara  75.0       3
# 644           Baclini, Miss. Eugenie  75.0       3
# 78     Caldwell, Master. Alden Gates  83.0       2
#
# Top 5 oldest passengers:
#                                      Name     Age  Pclass
# 116                  Connors, Mr. Patrick  7050.0       3
# 493               Artagaveytia, Mr. Ramon  7100.0       1
# 96              Goldschmidt, Mr. George B  7100.0       1
# 851                   Svensson, Mr. Johan  7400.0       3
# 630  Barkworth, Mr. Algernon Henry Wilson  8000.0       1

# %%
pd.crosstab(df['Pclass'],df['Survived'])     #for when both variables are catagorical
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.countplot(x = 'Pclass', hue = 'Survived' , data = df)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>
